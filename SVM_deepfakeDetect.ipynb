# %%
import os
import shutil
import numpy as np
from PIL import Image

# %% [markdown]
# <h3>SVM</h3>

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog, local_binary_pattern
from scipy.spatial.distance import euclidean
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC


def extract_hog_features(image, orientations=9):
    hog_features, hog_image = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), 
                                   block_norm='L2-Hys', visualize=True, feature_vector=True)
    return hog_features

def extract_lbp_features(image):
    # Set the parameters for LBP
    radius = 1
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, method="uniform")
    
    # Compute the histogram of LBP
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    # Normalize the histogram
    hist = hist.astype("float")
    hist /= hist.sum()
    
    return hist

def crop_center(image, crop_size=128):
    h, w = image.shape
    center_h, center_w = h // 2, w // 2
    half_crop = crop_size // 2
    cropped_image = image[center_h - half_crop:center_h + half_crop, center_w - half_crop:center_w + half_crop]
    return cropped_image

X = []
y = []
parent_path = "archive/similar/inpainting"

for folder_name in os.listdir(parent_path):
    folder_path = os.path.join(parent_path, folder_name)
    if os.path.isdir(folder_path):
        real_img = None
        forged_img = None
        print("reading folder " + folder_name)
        for image in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image)
            if os.path.isfile(image_path):
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

                if img is not None:
                    h, w = img.shape

                    # Skip images with height or width smaller than 256px
                    if h < 128 or w < 128:
                        print(f"Skipping image {image_path} (size: {h}x{w})")
                        continue  # Skip this image

                    if image.startswith("original"):
                        real_img = img
                    elif image.startswith("inpainting"):
                        forged_img = img

        if real_img is not None and forged_img is not None:
            real_img_cropped = crop_center(real_img)
            forged_img_cropped = crop_center(forged_img)

            real_hog = extract_hog_features(real_img_cropped)
            forged_hog = extract_hog_features(forged_img_cropped)

            real_lbp = extract_lbp_features(real_img_cropped)
            forged_lbp = extract_lbp_features(forged_img_cropped)

            combined_features = np.hstack((real_hog, real_lbp))
            X.append(combined_features)  
            y.append(0)  

            combined_features = np.hstack((forged_hog, forged_lbp))
            X.append(combined_features)
            y.append(1)  

X = np.array(X)
y = np.array(y)

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog, local_binary_pattern
from scipy.spatial.distance import euclidean
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
model_map = {"svm_linear": SVC(kernel = "linear"),
             "svm_rbf": SVC(kernel = "rbf"),
            "svm_poly": SVC(kernel = "poly")}

parameters_map = { 
    "C": [0.01, 0.1, 1, 10, 100],
    "gamma": [0.001, 0.01, 0.1, 1],
    "degree": [2, 3, 4, 5] 
}

def fine_tune(model: str, param_grid: dict, folds:int = 3):
    return HalvingGridSearchCV(model_map[model], param_grid, n_jobs = -1, refit = True, cv = folds, verbose = 3, factor = 3, resource = "n_samples")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# linear
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, HalvingGridSearchCV
linear_svm = fine_tune("svm_linear", parameters_map)
linear_svm.fit(X_train, y_train)

# %%
print(f"Grid search linear SVM best parameters: {linear_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {linear_svm.best_score_}")

# %%
y_pred = linear_svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)  
print(f"Accuracy: {accuracy * 100:.2f}%")

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# polynomial
poly_svm = fine_tune("svm_poly", parameters_map)
poly_svm.fit(X_train, y_train)

# %%
print(f"Grid search linear SVM best parameters: {poly_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {poly_svm.best_score_}")

# %%
y_pred_poly = poly_svm.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_poly)  
print(f"Accuracy: {accuracy * 100:.2f}%")

conf_matrix = confusion_matrix(y_test, y_pred_poly)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred_poly)
recall = recall_score(y_test, y_pred_poly)
f1 = f1_score(y_test, y_pred_poly)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# rbf
rbf_svm = fine_tune("svm_rbf", parameters_map)
rbf_svm.fit(X_train, y_train)

# %%
print(f"Grid search linear SVM best parameters: {rbf_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {rbf_svm.best_score_}")

# %%
y_pred_rbf = rbf_svm.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_rbf)  
print(f"Accuracy: {accuracy * 100:.2f}%")

conf_matrix = confusion_matrix(y_test, y_pred_rbf)
print("Confusion Matrix:")
print(conf_matrix)

precision = precision_score(y_test, y_pred_rbf)
recall = recall_score(y_test, y_pred_rbf)
f1 = f1_score(y_test, y_pred_rbf)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %% [markdown]
# <h3>CNN-SVM</h3>

# %%
# Define the source directory
source_dir = 'archive/similar/inpainting'

# Define the destination directories
original_dest = 'extracted_images/original'
inpainting_dest = 'extracted_images/inpainting'

# Create destination directories if they don't exist
os.makedirs(original_dest, exist_ok=True)
os.makedirs(inpainting_dest, exist_ok=True)

# Counter for naming files
counter = 1

# Walk through the source directory
for root, dirs, files in os.walk(source_dir):
    original_file = os.path.join(root, 'original.png')
    inpainting_file = os.path.join(root, 'inpainting.png')
    
    # Check if both files exist in the current directory
    if os.path.exists(original_file) and os.path.exists(inpainting_file):
        # Copy original image
        shutil.copy2(original_file, os.path.join(original_dest, f'original_{counter}.png'))
        
        # Copy inpainting image
        shutil.copy2(inpainting_file, os.path.join(inpainting_dest, f'inpainting_{counter}.png'))
        
        counter += 1

print(f"Extracted {counter-1} pairs of images.")
# Out:
# Extracted 5063 pairs of images.

# %%
from concurrent.futures import ThreadPoolExecutor
import tqdm

# Define directories
source_dir = 'archive/similar/inpainting'
original_dest = 'mask_images/original'
inpainting_dest = 'mask_images/inpainting'

# Create destination directories
os.makedirs(original_dest, exist_ok=True)
os.makedirs(inpainting_dest, exist_ok=True)

def apply_mask(image_path, mask_path):
    image = Image.open(image_path).convert('RGBA')
    mask = Image.open(mask_path).convert('L')
    
    # Convert images to numpy arrays
    image_array = np.array(image)
    mask_array = np.array(mask)
    
    # Create an all transparent image
    result = np.zeros_like(image_array)
    
    # Copy only the pixels where the mask is white (255)
    result[mask_array == 255] = image_array[mask_array == 255]
    
    return Image.fromarray(result)

def process_folder(folder_path):
    folder_name = os.path.basename(folder_path)
    original_file = os.path.join(folder_path, 'original.png')
    inpainting_file = os.path.join(folder_path, 'inpainting.png')
    mask_file = os.path.join(folder_path, 'mask.png')
    
    if all(os.path.exists(f) for f in [original_file, inpainting_file, mask_file]):
        # Apply mask to original image and save
        masked_original = apply_mask(original_file, mask_file)
        masked_original.save(os.path.join(original_dest, f'masked_original_{folder_name}.png'))
        
        # Apply mask to inpainting image and save
        masked_inpainting = apply_mask(inpainting_file, mask_file)
        masked_inpainting.save(os.path.join(inpainting_dest, f'masked_inpainting_{folder_name}.png'))
        
        return True
    return False

# Get list of folders
folders = [os.path.join(source_dir, d) for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]

# Use ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor() as executor:
    results = list(tqdm.tqdm(executor.map(process_folder, folders), total=len(folders)))

processed_count = sum(results)
print(f"Extracted and masked {processed_count} pairs of images.")
# Out:
# 100%|███████████████████████████████████████| 5063/5063 [22:35<00:00,  3.74it/s]
# Extracted and masked 5063 pairs of images.

# %%
import cv2
def load_image_paths_from_folder(folder, label):
    image_paths = []
    labels = []
    for filename in os.listdir(folder):
        if filename.endswith((".png", ".jpg", ".jpeg")):
            img_path = os.path.join(folder, filename)
            image_paths.append(img_path)
            labels.append(label)
    return image_paths, labels

# Load real image paths (label = 1)
# real_folder = "extracted_images/original"
real_folder = "mask_images/original"
real_image_paths, real_labels = load_image_paths_from_folder(real_folder, label=1)

# Load fake image paths (label = 0)
# fake_folder = "extracted_images/inpainting"
fake_folder = "mask_images/inpainting"
fake_image_paths, fake_labels = load_image_paths_from_folder(fake_folder, label=0)

# Combine real and fake image paths and labels
image_paths = real_image_paths + fake_image_paths
labels = real_labels + fake_labels

# Convert labels to NumPy array
labels = np.array(labels)

# Check number of images loaded
print(f"Number of real images: {len(real_image_paths)}")
print(f"Number of fake images: {len(fake_image_paths)}")
print(f"Total number of images: {len(image_paths)}")

# Function to load and preprocess images (to be used when training the model)
def load_and_preprocess_image(image_path, target_size=(256, 256), preserve_texture=True):
    img = Image.open(image_path)
    img = img.convert('RGB')  # Convert to RGB
    if preserve_texture:
        # Convert to numpy array for OpenCV processing
        img_array = np.array(img)
        
        # Use Lanczos resampling which better preserves high-frequency details
        img_array = cv2.resize(
            img_array, 
            target_size, 
            interpolation=cv2.INTER_LANCZOS4
        )
    else:
        img = img.resize(target_size)  # Resize the image
        img_array = np.array(img)

    img_array = img_array.astype(np.float32)
    img_array /= 255.0  # Normalize to [0, 1]
    return img_array

# %%
from sklearn.model_selection import train_test_split
# Perform train-test split
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.2, random_state=42, stratify=labels
)

# Print the shapes of the resulting datasets
print("\nAfter train-test split:")
print(f"Train set size: {len(train_paths)}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Test set size: {len(test_paths)}")
print(f"Test labels shape: {test_labels.shape}")

# Print the distribution of labels in train and test sets
print(f"\nTrain set - Real: {np.sum(train_labels == 1)}, Fake: {np.sum(train_labels == 0)}")
print(f"Test set - Real: {np.sum(test_labels == 1)}, Fake: {np.sum(test_labels == 0)}")
# Out:
# After train-test split:
# Train set size: 8100
# Train labels shape: (8100,)
# Test set size: 2026
# Test labels shape: (2026,)
#
# Train set - Real: 4050, Fake: 4050
# Test set - Real: 1013, Fake: 1013

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.regularizers import l2

def improved_deepfake_detection_model(input_shape=(256, 256, 3)):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    x = Conv2D(32, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    x = Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    x = Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    # Additional convolutional layer
    x = Conv2D(256, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    
    # Dense layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)
    
    # Final layer
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Create the model
model = improved_deepfake_detection_model()

# Print model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 32)      896
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)      128
#  chNormalization)
#
#  activation_9 (Activation)   (None, 256, 256, 32)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 64)      18496
#
#  batch_normalization_9 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_11 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 256)               0
#  GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  batch_normalization_12 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  batch_normalization_13 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 490689 (1.87 MB)
# Trainable params: 488961 (1.87 MB)
# Non-trainable params: 1728 (6.75 KB)
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 32)      896
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)      128
#  chNormalization)
#
#  activation_9 (Activation)   (None, 256, 256, 32)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 64)      18496
#
#  batch_normalization_9 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_11 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 256)               0
#  GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  batch_normalization_12 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  batch_normalization_13 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 490689 (1.87 MB)
# Trainable params: 488961 (1.87 MB)
# Non-trainable params: 1728 (6.75 KB)
# _________________________________________________________________

# %%
# view keys for 0.60 weights
import h5py

with h5py.File('model_weights_cnn/model_weights_epoch_05_val_loss_0.60.weights.h5', 'r') as h5file:
    print("Keys in the file:")
    for key in h5file.keys():
        print(key)
# Out:
# Keys in the file:
# activation_4
# activation_5
# activation_6
# activation_7
# batch_normalization_10
# batch_normalization_11
# batch_normalization_6
# batch_normalization_7
# batch_normalization_8
# batch_normalization_9
# conv2d_4
# conv2d_5
# conv2d_6
# conv2d_7
# dense_3
# dense_4
# dense_5
# dropout_2
# dropout_3
# global_average_pooling2d_1
# input_2
# max_pooling2d_4
# max_pooling2d_5
# max_pooling2d_6
# max_pooling2d_7
# top_level_model_weights

# %%
# view keys for 0.57 weights
import h5py

with h5py.File('model_weights_cnn/model_weights_epoch_04_val_loss_0.57.weights.h5', 'r') as h5file:
    print("Keys in the file:")
    for key in h5file.keys():
        print(key)
# Out:
# Keys in the file:
# activation_12
# activation_13
# activation_14
# activation_15
# batch_normalization_18
# batch_normalization_19
# batch_normalization_20
# batch_normalization_21
# batch_normalization_22
# batch_normalization_23
# conv2d_12
# conv2d_13
# conv2d_14
# conv2d_15
# dense_10
# dense_11
# dense_9
# dropout_6
# dropout_7
# global_average_pooling2d_3
# input_4
# max_pooling2d_12
# max_pooling2d_13
# max_pooling2d_14
# max_pooling2d_15
# top_level_model_weights

# %%
# loading weights

with h5py.File('model_weights_cnn/model_weights_epoch_04_val_loss_0.57.weights.h5', 'r') as h5file:
    weights_group = h5file['top_level_model_weights']
    
    # Iterate over the layers in the model and set weights
    for layer in model.layers:
        if layer.name in weights_group:
            layer_weights = [weights_group[layer.name][w] for w in weights_group[layer.name]]
            layer.set_weights(layer_weights)

print("Weights loaded successfully!")
# Out:
# Weights loaded successfully!

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 32)      896
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)      128
#  chNormalization)
#
#  activation_9 (Activation)   (None, 256, 256, 32)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 64)      18496
#
#  batch_normalization_9 (Bat  (None, 128, 128, 64)      256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 64)      0
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 64, 64, 128)       512
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 128)       0
#
#  max_pooling2d_7 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)       295168
#
#  batch_normalization_11 (Ba  (None, 32, 32, 256)       1024
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 256)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 256)               0
#  GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  batch_normalization_12 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  batch_normalization_13 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 490689 (1.87 MB)
# Trainable params: 488961 (1.87 MB)
# Non-trainable params: 1728 (6.75 KB)
# _________________________________________________________________

# %% [markdown]
# <b>Testing global_average_pooling2d layer</b>

# %%
# Function to extract features using the CNN
def extract_features(image_paths, model):
    features = []
    for img_path in image_paths:
        img_array = load_and_preprocess_image(img_path, target_size=(256, 256))
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Extract features
        feature = model.predict(img_array)
        features.append(feature.flatten()) 
    return np.array(features)

# Extract features from convolutional layer
# Change this accordingly to the conv layer u wan to extract
feature_extractor = Model(inputs=model.input, outputs=model.get_layer('global_average_pooling2d').output)

# Extract features
features = extract_features(image_paths, feature_extractor)
# Out:
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# ...
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 18
#      15 feature_extractor = Model(inputs=model.input, outputs=model.get_layer('global_average_pooling2d').output)
#      17 # Extract features
# ---> 18 features = extract_features(image_paths, feature_extractor)
#
# Cell In[20], line 5, in extract_features(image_paths, model)
#       3 features = []
#       4 for img_path in image_paths:
# ----> 5     img_array = load_and_preprocess_image(img_path, target_size=(256, 256))
#       6     img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
#       8     # Extract features
#
# Cell In[5], line 37, in load_and_preprocess_image(image_path, target_size, preserve_texture)
#      35 def load_and_preprocess_image(image_path, target_size=(256, 256), preserve_texture=True):
#      36     img = Image.open(image_path)
# ---> 37     img = img.convert('RGB')  # Convert to RGB
#      38     if preserve_texture:
#      39         # Convert to numpy array for OpenCV processing
#      40         img_array = np.array(img)
#
# File ~/anaconda3/lib/python3.11/site-packages/PIL/Image.py:993, in Image.convert(self, mode, matrix, dither, palette, colors)
#     990 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     991     deprecate(mode, 12)
# --> 993 self.load()
#     995 has_transparency = "transparency" in self.info
#     996 if not mode and self.mode == "P":
#     997     # determine default mode
#
# File ~/anaconda3/lib/python3.11/site-packages/PIL/ImageFile.py:300, in ImageFile.load(self)
#     297         raise OSError(msg)
#     299 b = b + s
# --> 300 n, err_code = decoder.decode(b)
#     301 if n < 0:
#     302     break
#
# KeyboardInterrupt:

# %%
np.save('global_average_pooling2d.npy', features)  # Saves as a .npy file
print("saved")

# %%
# can try PCA afterwards, run above without PCA first // can adjust variance %

# import numpy as np
# from sklearn import svm
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.metrics import classification_report, accuracy_score


# train_paths, test_paths, train_labels, test_labels = train_test_split(
#     features, labels, test_size=0.2, random_state=42, stratify=labels
# )

# # Step 2: Standardize the features
# scaler = StandardScaler()
# train_paths = scaler.fit_transform(train_paths)
# test_paths = scaler.transform(test_paths)

# # Step 3: Apply PCA
# pca = PCA(n_components=0.85)  # Retain 85% of the variance
# train_paths = pca.fit_transform(train_paths)
# test_paths = pca.transform(test_paths)

# %%
from sklearn.svm import SVC

model_map = {"svm_linear": SVC(kernel = "linear"),
             "svm_rbf": SVC(kernel = "rbf"),
            "svm_poly": SVC(kernel = "poly")}

parameters_map = { 
    "C": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],  # Further expanded range
    "gamma": [0.0001, 0.001, 0.01, 0.1, 1, 10],  # Further expanded range
    "degree": [2, 3, 4, 5, 6]  # Added more degrees for poly kernel
}


def fine_tune(model: str, param_grid: dict, folds:int = 3):
    return HalvingGridSearchCV(model_map[model], param_grid, n_jobs = -1, refit = True, cv = folds, verbose = 3, factor = 3, resource = "n_samples")

# %%
# linear

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, HalvingGridSearchCV

linear_svm = fine_tune("svm_linear", parameters_map)
linear_svm.fit(train_paths, train_labels)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 240
# n_resources: 100
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# python(77522) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77523) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77524) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77525) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77526) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77527) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77528) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(77529) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[232], line 6
#       4 from sklearn.model_selection import train_test_split, HalvingGridSearchCV
#       5 linear_svm = fine_tune("svm_linear", parameters_map)
# ----> 6 linear_svm.fit(train_paths, train_labels)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search_successive_halving.py:251, in BaseSuccessiveHalving.fit(self, X, y, **params)
#     245 self._check_input_parameters(
#     246     X=X, y=y, split_params=routed_params.splitter.split
#     247 )
#     249 self._n_samples_orig = _num_samples(X)
# --> 251 super().fit(X, y=y, **params)
#     253 # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#     254 self.best_score_ = self.cv_results_["mean_test_score"][self.best_index_]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search_successive_halving.py:355, in BaseSuccessiveHalving._run_search(self, evaluate_candidates)
#     348     cv = self._checked_cv_orig
#     350 more_results = {
#     351     "iter": [itr] * n_candidates,
#     352     "n_resources": [n_resources] * n_candidates,
#     353 }
# --> 355 results = evaluate_candidates(
#     356     candidate_params, cv, more_results=more_results
#     357 )
#     359 n_candidates_to_keep = ceil(n_candidates / self.factor)
#     360 candidate_params = _top_k(results, n_candidates_to_keep, itr)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
print(f"Grid search linear SVM best parameters: {linear_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {linear_svm.best_score_}")
# Out:
# Grid search linear SVM best parameters: {'C': 1, 'degree': 4, 'gamma': 0.1}
# Cross validated score of the best linear SVM model: 0.6830864197530865

# %%
y_pred = linear_svm.predict(test_paths)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred)
recall = recall_score(test_labels, y_pred)
f1 = f1_score(test_labels, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 66.49%
# Confusion Matrix:
# [[704 309]
#  [370 643]]
# Precision: 0.68
# Recall: 0.63
# F1 Score: 0.65

# %%
# polynomial

poly_svm = fine_tune("svm_poly", parameters_map)
poly_svm.fit(train_paths, train_labels)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 240
# n_resources: 100
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# ----------
# iter: 1
# n_candidates: 80
# n_resources: 300
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# ----------
# iter: 2
# n_candidates: 27
# n_resources: 900
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# ----------
# iter: 3
# n_candidates: 9
# n_resources: 2700
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# ----------
# iter: 4
# n_candidates: 3
# n_resources: 8100
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END C=0.0001, degree=2, gamma=0.01;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=2, gamma=0.01;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=2, gamma=1;, score=(train=0.621, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=4, gamma=0.0001;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=4, gamma=0.001;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=4, gamma=0.01;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=4, gamma=0.1;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=4, gamma=10;, score=(train=0.621, test=0.455) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=4, gamma=10;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=5, gamma=0.01;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=5, gamma=0.1;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=5, gamma=10;, score=(train=0.621, test=0.455) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=5, gamma=10;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=6, gamma=1;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=6, gamma=1;, score=(train=0.621, test=0.455) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=6, gamma=1;, score=(train=0.606, test=0.576) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=6, gamma=10;, score=(train=0.591, test=0.333) total time=   0.0s
# [CV 3/3] END C=100, degree=3, gamma=0.01;, score=(train=0.830, test=0.613) total time=   0.1s
# [CV 2/3] END C=1000, degree=3, gamma=0.01;, score=(train=0.953, test=0.597) total time=   0.2s
# [CV 3/3] END C=1, degree=3, gamma=0.1;, score=(train=0.960, test=0.620) total time=   0.2s
# [CV 3/3] END C=0.0001, degree=2, gamma=10;, score=(train=0.825, test=0.600) total time=   0.1s
# [CV 3/3] END C=0.001, degree=6, gamma=0.1;, score=(train=0.828, test=0.623) total time=   0.1s
# [CV 1/3] END C=1, degree=3, gamma=0.1;, score=(train=0.918, test=0.650) total time=   4.9s
# [CV 2/3] END C=1, degree=3, gamma=0.1;, score=(train=0.923, test=0.623) total time=   2.4s
# [CV 2/3] END C=1000, degree=3, gamma=0.01;, score=(train=0.864, test=0.686) total time= 1.2min
# [CV 1/3] END C=0.0001, degree=2, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=2, gamma=0.1;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=2, gamma=1;, score=(train=0.667, test=0.485) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=2, gamma=10;, score=(train=0.939, test=0.515) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=2, gamma=10;, score=(train=0.985, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=3, gamma=0.01;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=3, gamma=0.1;, score=(train=0.545, test=0.606) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=3, gamma=10;, score=(train=1.000, test=0.576) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=3, gamma=10;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=4, gamma=0.01;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=4, gamma=0.01;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=5, gamma=1;, score=(train=1.000, test=0.515) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=5, gamma=10;, score=(train=1.000, test=0.697) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=5, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=5, gamma=10;, score=(train=1.000, test=0.515) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=6, gamma=0.01;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=6, gamma=0.1;, score=(train=0.803, test=0.667) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=6, gamma=0.1;, score=(train=0.788, test=0.515) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=6, gamma=0.1;, score=(train=0.864, test=0.515) total time=   0.0s
# [CV 3/3] END C=0.001, degree=2, gamma=1;, score=(train=0.848, test=0.606) total time=   0.0s
# [CV 1/3] END C=0.001, degree=2, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=0.001, degree=2, gamma=10;, score=(train=1.000, test=0.636) total time=   0.0s
# [CV 3/3] END C=0.001, degree=2, gamma=10;, score=(train=1.000, test=0.424) total time=   0.0s
# [CV 3/3] END C=0.001, degree=5, gamma=0.01;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.001, degree=5, gamma=0.1;, score=(train=0.848, test=0.636) total time=   0.0s
# [CV 2/3] END C=0.001, degree=5, gamma=0.1;, score=(train=0.818, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.001, degree=5, gamma=0.1;, score=(train=0.894, test=0.515) total time=   0.0s
# [CV 1/3] END C=0.001, degree=5, gamma=1;, score=(train=1.000, test=0.697) total time=   0.0s
# [CV 2/3] END C=0.001, degree=5, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=0.001, degree=5, gamma=1;, score=(train=1.000, test=0.515) total time=   0.0s
# [CV 1/3] END C=0.001, degree=5, gamma=10;, score=(train=1.000, test=0.697) total time=   0.0s
# [CV 1/3] END C=0.01, degree=2, gamma=1;, score=(train=0.970, test=0.667) total time=   0.0s
# [CV 2/3] END C=0.01, degree=2, gamma=1;, score=(train=0.939, test=0.515) total time=   0.0s
# [CV 3/3] END C=0.01, degree=2, gamma=1;, score=(train=0.985, test=0.545) total time=   0.0s
# [CV 1/3] END C=0.01, degree=2, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=0.01, degree=2, gamma=10;, score=(train=1.000, test=0.636) total time=   0.0s
# [CV 3/3] END C=0.01, degree=2, gamma=10;, score=(train=1.000, test=0.424) total time=   0.0s
# [CV 1/3] END C=0.01, degree=3, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.01, degree=3, gamma=0.0001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=1, degree=2, gamma=0.01;, score=(train=0.712, test=0.515) total time=   0.0s
# [CV 1/3] END C=1, degree=2, gamma=0.1;, score=(train=0.970, test=0.667) total time=   0.0s
# [CV 2/3] END C=1, degree=2, gamma=0.1;, score=(train=0.939, test=0.515) total time=   0.0s
# [CV 3/3] END C=1, degree=2, gamma=0.1;, score=(train=0.985, test=0.545) total time=   0.0s
# [CV 1/3] END C=1, degree=2, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=1, degree=2, gamma=1;, score=(train=1.000, test=0.636) total time=   0.0s
# [CV 3/3] END C=1, degree=2, gamma=1;, score=(train=1.000, test=0.424) total time=   0.0s
# [CV 1/3] END C=1, degree=2, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=1, degree=2, gamma=10;, score=(train=1.000, test=0.636) total time=   0.0s
# [CV 3/3] END C=1, degree=2, gamma=10;, score=(train=1.000, test=0.424) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=0.0001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 2/3] END C=10, degree=4, gamma=0.1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=10, degree=4, gamma=0.1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 2/3] END C=10, degree=4, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=10, degree=4, gamma=10;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 2/3] END C=10, degree=5, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=10, degree=5, gamma=10;, score=(train=1.000, test=0.515) total time=   0.0s
# [CV 1/3] END C=10, degree=6, gamma=0.01;, score=(train=0.712, test=0.636) total time=   0.0s
# [CV 2/3] END C=10, degree=6, gamma=0.01;, score=(train=0.742, test=0.515) total time=   0.0s
# [CV 3/3] END C=10, degree=6, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=10, degree=6, gamma=10;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=100, degree=3, gamma=0.001;, score=(train=0.561, test=0.545) total time=   0.0s
# [CV 3/3] END C=100, degree=3, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=100, degree=3, gamma=1;, score=(train=1.000, test=0.727) total time=   0.0s
# [CV 2/3] END C=100, degree=3, gamma=1;, score=(train=1.000, test=0.576) total time=   0.0s
# [CV 1/3] END C=100, degree=4, gamma=0.01;, score=(train=0.894, test=0.697) total time=   0.0s
# [CV 2/3] END C=100, degree=4, gamma=0.01;, score=(train=0.848, test=0.545) total time=   0.0s
# [CV 3/3] END C=100, degree=4, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=100, degree=4, gamma=10;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=100, degree=5, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=100, degree=5, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 3/3] END C=1000, degree=3, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=1000, degree=3, gamma=0.001;, score=(train=0.561, test=0.606) total time=   0.0s
# [CV 3/3] END C=1000, degree=3, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=1000, degree=3, gamma=10;, score=(train=1.000, test=0.727) total time=   0.0s
# [CV 1/3] END C=1000, degree=4, gamma=0.01;, score=(train=0.955, test=0.667) total time=   0.0s
# [CV 2/3] END C=1000, degree=4, gamma=0.01;, score=(train=0.955, test=0.515) total time=   0.0s
# [CV 3/3] END C=1000, degree=4, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=1000, degree=4, gamma=10;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=1000, degree=5, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=1000, degree=5, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=1000, degree=5, gamma=1;, score=(train=1.000, test=0.697) total time=   0.0s
# [CV 2/3] END C=1000, degree=5, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=1000, degree=6, gamma=0.1;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 3/3] END C=1000, degree=6, gamma=0.1;, score=(train=1.000, test=0.520) total time=   0.0s
# [CV 1/3] END C=0.1, degree=6, gamma=10;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 2/3] END C=0.1, degree=6, gamma=10;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 2/3] END C=0.01, degree=4, gamma=1;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 3/3] END C=0.01, degree=4, gamma=1;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 3/3] END C=0.1, degree=5, gamma=0.1;, score=(train=0.990, test=0.600) total time=   0.0s
# [CV 1/3] END C=0.001, degree=6, gamma=10;, score=(train=1.000, test=0.560) total time=   0.0s
# ...
# [CV 1/3] END C=100, degree=3, gamma=0.0001;, score=(train=0.560, test=0.520) total time=   0.0s
# [CV 2/3] END C=100, degree=3, gamma=0.0001;, score=(train=0.585, test=0.450) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=2, gamma=10;, score=(train=0.910, test=0.610) total time=   0.0s
# [CV 2/3] END C=0.0001, degree=2, gamma=10;, score=(train=0.915, test=0.570) total time=   0.0s
# [CV 2/3] END C=1, degree=2, gamma=0.01;, score=(train=0.620, test=0.580) total time=   0.0s
# [CV 3/3] END C=1, degree=2, gamma=0.01;, score=(train=0.652, test=0.633) total time=   0.0s
# [CV 1/3] END C=0.001, degree=2, gamma=1;, score=(train=0.742, test=0.627) total time=   0.0s
# [CV 3/3] END C=1000, degree=2, gamma=0.001;, score=(train=0.715, test=0.647) total time=   0.0s
# [CV 2/3] END C=0.1, degree=4, gamma=0.1;, score=(train=0.925, test=0.590) total time=   0.1s
# [CV 3/3] END C=1000, degree=4, gamma=0.01;, score=(train=0.912, test=0.613) total time=   0.1s
# [CV 1/3] END C=0.001, degree=3, gamma=1;, score=(train=0.958, test=0.660) total time=   0.3s
# [CV 3/3] END C=100, degree=2, gamma=0.01;, score=(train=0.825, test=0.600) total time=   0.1s
# [CV 2/3] END C=1000, degree=5, gamma=0.01;, score=(train=0.857, test=0.583) total time=   0.1s
# [CV 1/3] END C=0.01, degree=2, gamma=1;, score=(train=0.838, test=0.607) total time=   0.1s
# [CV 2/3] END C=0.001, degree=6, gamma=0.1;, score=(train=0.812, test=0.627) total time=   0.1s
# [CV 3/3] END C=0.001, degree=3, gamma=1;, score=(train=0.927, test=0.648) total time=   3.2s
# [CV 1/3] END C=1000, degree=3, gamma=0.01;, score=(train=0.918, test=0.650) total time=   4.4s
# [CV 2/3] END C=0.001, degree=3, gamma=1;, score=(train=0.863, test=0.686) total time= 1.2min
# [CV 1/3] END C=0.0001, degree=2, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 3/3] END C=0.0001, degree=2, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=0.01, degree=4, gamma=10;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=0.01, degree=5, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.01, degree=5, gamma=0.0001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.01, degree=5, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.01, degree=5, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.01, degree=5, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.01, degree=5, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 3/3] END C=0.1, degree=4, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=0.1, degree=4, gamma=10;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=0.1, degree=4, gamma=10;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=0.1, degree=4, gamma=10;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=0.1, degree=5, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.1, degree=5, gamma=0.0001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.1, degree=5, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.1, degree=5, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.1, degree=5, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.1, degree=5, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=0.1, degree=5, gamma=0.01;, score=(train=0.545, test=0.576) total time=   0.0s
# [CV 2/3] END C=0.1, degree=5, gamma=0.01;, score=(train=0.591, test=0.545) total time=   0.0s
# [CV 3/3] END C=0.1, degree=5, gamma=0.01;, score=(train=0.606, test=0.485) total time=   0.0s
# [CV 1/3] END C=0.1, degree=5, gamma=0.1;, score=(train=0.970, test=0.636) total time=   0.0s
# [CV 2/3] END C=0.1, degree=5, gamma=0.1;, score=(train=0.970, test=0.636) total time=   0.0s
# [CV 3/3] END C=0.1, degree=5, gamma=0.1;, score=(train=0.985, test=0.545) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=0.01;, score=(train=0.561, test=0.606) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=0.01;, score=(train=0.652, test=0.515) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=0.01;, score=(train=0.621, test=0.485) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=0.1;, score=(train=1.000, test=0.727) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=0.1;, score=(train=1.000, test=0.576) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=0.1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=1;, score=(train=1.000, test=0.727) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=1;, score=(train=1.000, test=0.576) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=1;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=1, degree=3, gamma=10;, score=(train=1.000, test=0.727) total time=   0.0s
# [CV 2/3] END C=1, degree=3, gamma=10;, score=(train=1.000, test=0.576) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=10;, score=(train=1.000, test=0.545) total time=   0.0s
# [CV 1/3] END C=1, degree=4, gamma=0.0001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=1, degree=4, gamma=0.0001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=1, degree=4, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=1, degree=4, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=10, degree=5, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=10, degree=5, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=10, degree=5, gamma=1;, score=(train=1.000, test=0.697) total time=   0.0s
# [CV 2/3] END C=10, degree=5, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=100, degree=2, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=100, degree=2, gamma=0.001;, score=(train=0.576, test=0.636) total time=   0.0s
# [CV 1/3] END C=100, degree=2, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 2/3] END C=100, degree=2, gamma=1;, score=(train=1.000, test=0.636) total time=   0.0s
# [CV 1/3] END C=100, degree=4, gamma=1;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=100, degree=4, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=100, degree=5, gamma=0.0001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=100, degree=5, gamma=0.001;, score=(train=0.515, test=0.576) total time=   0.0s
# [CV 2/3] END C=100, degree=5, gamma=0.1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 3/3] END C=100, degree=5, gamma=0.1;, score=(train=1.000, test=0.515) total time=   0.0s
# [CV 2/3] END C=100, degree=6, gamma=0.001;, score=(train=0.545, test=0.545) total time=   0.0s
# [CV 3/3] END C=100, degree=6, gamma=0.001;, score=(train=0.606, test=0.455) total time=   0.0s
# [CV 1/3] END C=100, degree=6, gamma=1;, score=(train=1.000, test=0.606) total time=   0.0s
# [CV 2/3] END C=100, degree=6, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV 1/3] END C=1000, degree=2, gamma=1;, score=(train=1.000, test=0.667) total time=   0.0s
# [CV
# [CV 2/3] END C=0.1, degree=3, gamma=1;, score=(train=1.000, test=0.610) total time=   0.0s
# [CV 3/3] END C=0.1, degree=3, gamma=1;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 2/3] END C=100, degree=3, gamma=0.1;, score=(train=1.000, test=0.610) total time=   0.0s
# [CV 3/3] END C=100, degree=3, gamma=0.1;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/3] END C=1000, degree=5, gamma=10;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 1/3] END C=0.0001, degree=5, gamma=10;, score=(train=1.000, test=0.590) total time=   0.0s
# [CV 1/3] END C=1, degree=5, gamma=10;, score=(train=1.000, test=0.590) total time=   0.0s
# [CV 2/3] END C=1, degree=5, gamma=10;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 1/3] END C=0.001, degree=5, gamma=1;, score=(train=1.000, test=0.590) total time=   0.0s
# [CV 2/3] END C=0.001, degree=5, gamma=1;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 3/3] END C=0.01, degree=5, gamma=1;, score=(train=1.000, test=0.580) total time=   0.0s
# [CV 1/3] END C=0.01, degree=5, gamma=10;, score=(train=1.000, test=0.590) total time=   0.0s
# [CV 2/3] END C=0.001, degree=5, gamma=10;, score=(train=1.000, test=0.587) total time=   0.2s
# [CV 3/3] END C=0.001, degree=5, gamma=10;, score=(train=1.000, test=0.627) total time=   0.3s
# [CV 3/3] END C=100, degree=5, gamma=1;, score=(train=1.000, test=0.627) total time=   0.3s
# [CV 3/3] END C=100, degree=5, gamma=0.1;, score=(train=1.000, test=0.627) total time=   0.3s
# [CV 2/3] END C=1000, degree=5, gamma=0.1;, score=(train=1.000, test=0.587) total time=   0.2s
# [CV 3/3] END C=1, degree=6, gamma=0.1;, score=(train=0.997, test=0.570) total time=   0.3s
# [CV 2/3] END C=100, degree=5, gamma=10;, score=(train=1.000, test=0.587) total time=   0.2s
# [CV 2/3] END C=0.001, degree=2, gamma=1;, score=(train=0.737, test=0.630) total time=   0.0s
# [CV 3/3] END C=1, degree=3, gamma=0.1;, score=(train=0.963, test=0.623) total time=   0.3s
# [CV 3/3] END C=0.001, degree=3, gamma=1;, score=(train=0.963, test=0.623) total time=   0.3s
# [CV 3/3] END C=10, degree=5, gamma=1;, score=(train=1.000, test=0.609) total time=  12.3s
# [CV 1/3] END C=100, degree=5, gamma=0.1;, score=(train=1.000, test=0.648) total time=  26.1s
# [CV 3/3] END C=0.001, degree=3, gamma=1;, score=(train=0.908, test=0.639) total time=   5.6s
# [CV 3/3] END C=0.01, degree=5, gamma=1;, score=(train=1.000, test=0.609) total time=  10.8s
# [CV 3/3] END C=1000, degree=5, gamma=1;, score=(train=1.000, test=0.639) total time=12.9min

# %%
print(f"Grid search poly SVM best parameters: {poly_svm.best_params_}")
print(f"Cross validated score of the best poly SVM model: {poly_svm.best_score_}")
# Out:
# Grid search poly SVM best parameters: {'C': 0.001, 'degree': 3, 'gamma': 1}
# Cross validated score of the best poly SVM model: 0.675679012345679

# %%
y_pred_poly = poly_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_poly)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_poly)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_poly)
recall = recall_score(test_labels, y_pred_poly)
f1 = f1_score(test_labels, y_pred_poly)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 66.04%
# Confusion Matrix:
# [[734 279]
#  [409 604]]
# Precision: 0.68
# Recall: 0.60
# F1 Score: 0.64

# %%
# rbf

rbf_svm = fine_tune("svm_rbf", parameters_map)
rbf_svm.fit(train_paths, train_labels)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 240
# n_resources: 100
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# ----------
# iter: 1
# n_candidates: 80
# n_resources: 300
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# ----------
# iter: 2
# n_candidates: 27
# n_resources: 900
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# ----------
# iter: 3
# n_candidates: 9
# n_resources: 2700
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# ----------
# iter: 4
# n_candidates: 3
# n_resources: 8100
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# HalvingGridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#                     param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                       1000],
#                                 'degree': [2, 3, 4, 5, 6],
#                                 'gamma': [0.0001, 0.001, 0.01, 0.1, 1, 10]},
#                     verbose=3)

# %%
# Check the best parameters
print("Best parameters found:", rbf_svm.best_params_)

# Check the kernel of the best estimator
print("Kernel used:", rbf_svm.best_estimator_.kernel)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 240
# n_resources: 100
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# ----------
# iter: 1
# n_candidates: 80
# n_resources: 300
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# ----------
# iter: 2
# n_candidates: 27
# n_resources: 900
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# ----------
# iter: 3
# n_candidates: 9
# n_resources: 2700
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# ----------
# iter: 4
# n_candidates: 3
# n_resources: 8100
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# Best parameters found: {'C': 100, 'degree': 5, 'gamma': 0.001}
# Kernel used: rbf

# %%
y_pred_rbf = rbf_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_rbf)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_rbf)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_rbf)
recall = recall_score(test_labels, y_pred_rbf)
f1 = f1_score(test_labels, y_pred_rbf)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 70.34%
# Confusion Matrix:
# [[779 234]
#  [367 646]]
# Precision: 0.73
# Recall: 0.64
# F1 Score: 0.68

# %%
# testing out ensemble model (catboost + rbf) // 69.79% compared to just rbf of 70.34%

from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

# Define the parameter grid for SVC
svc_parameters_map = {
    'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
    'gamma': [0.001, 0.01, 0.1, 1],
    'degree': [2, 3, 4, 5],
    'probability': [True]  
}

rbf_svm = SVC(kernel='rbf')

rbf_svm = HalvingGridSearchCV(
    estimator=rbf_svm,
    param_grid=svc_parameters_map,
    n_jobs=-1,
    refit=True,
    cv=3,
    verbose=3,
    factor=3,
    resource='n_samples'
)

rbf_svm.fit(train_paths, train_labels)

catboost_parameters_map = {
    'iterations': [100, 200],
    'depth': [4, 6, 8],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [1, 3, 5]
}

cat_clf = CatBoostClassifier(verbose=0, random_state=42)

catboost_search = HalvingGridSearchCV(
    estimator=cat_clf,
    param_grid=catboost_parameters_map,
    n_jobs=-1,
    refit=True,
    cv=3,
    verbose=3,
    factor=3,
    resource='n_samples'
)

catboost_search.fit(train_paths, train_labels)

# Create the ensemble model (Voting Classifier)
voting_clf = VotingClassifier(
    estimators=[
        ('cat', catboost_search.best_estimator_),
        ('rbf', rbf_svm.best_estimator_)
    ],
    voting='soft'
)

# Train the ensemble model
voting_clf.fit(train_paths, train_labels)

# Make predictions
y_pred = voting_clf.predict(test_paths)

# Evaluate the ensemble model
accuracy = accuracy_score(test_labels, y_pred)
print(f"Ensemble Model Accuracy: {accuracy}")
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 112
# n_resources: 100
# Fitting 3 folds for each of 112 candidates, totalling 336 fits
# ----------
# iter: 1
# n_candidates: 38
# n_resources: 300
# Fitting 3 folds for each of 38 candidates, totalling 114 fits
# ----------
# iter: 2
# n_candidates: 13
# n_resources: 900
# Fitting 3 folds for each of 13 candidates, totalling 39 fits
# ----------
# iter: 3
# n_candidates: 5
# n_resources: 2700
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# ----------
# iter: 4
# n_candidates: 2
# n_resources: 8100
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 300
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 36
# n_resources: 300
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# ----------
# iter: 1
# n_candidates: 12
# n_resources: 900
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# ----------
# iter: 2
# n_candidates: 4
# n_resources: 2700
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 8100
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# Ensemble Model Accuracy: 0.4980256663376111

# %%
from sklearn import svm
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
# Best parameters found: {'C': 1000, 'degree': 4, 'gamma': 0.0001}
#     {'C': 1, 'degree': 3, 'gamma': 0.01}
#     {'C': 1, 'degree': 4, 'gamma': 0.0001}

svm_rbf = svm.SVC(kernel='rbf', C=1000, degree=4, gamma=0.0001, probability=True)
svm_linear = svm.SVC(kernel='linear', C=1.0, degree=4, gamma=0.001, probability=True)
svm_poly = svm.SVC(kernel='poly', C=1.0, degree=4, gamma=0.0001, probability=True)

# Create an ensemble using VotingClassifier
ensemble_model = VotingClassifier(estimators=[
    ('rbf', svm_rbf),
    ('linear', svm_linear),
    ('poly', svm_poly)],
    voting='soft'  # Use 'soft' for probability-based voting
)

# Train the ensemble model
ensemble_model.fit(train_paths, train_labels)


# Evaluate the ensemble model
accuracy = ensemble_model.score(test_paths, test_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# <b>Testing conv2d_10 layer</b>

# %%
from tensorflow.keras.models import Model

# Function to extract features using the CNN
def extract_features(image_paths, model):
    features = []
    for img_path in image_paths:
        img_array = load_and_preprocess_image(img_path, target_size=(256, 256))
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Extract features
        feature = model.predict(img_array)
        features.append(feature.flatten())  # Flatten if necessary
    return np.array(features)

# extract features, from conv2d_9 layer
feature_extractor = Model(inputs=model.input, outputs=model.get_layer('conv2d_10').output)

# Extract features
features = extract_features(image_paths, feature_extractor)

# %%
np.save('features_conv2d_10.npy', features)  # Saves as a .npy file
print("saved")

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

train_paths, test_paths, train_labels, test_labels = train_test_split(
    features_dense2, labels, test_size=0.2, random_state=42, stratify=labels
)

scaler = StandardScaler()

train_paths = scaler.fit_transform(train_paths)
test_paths = scaler.transform(test_paths)

# %%
# can try PCA afterwards, run above without PCA first // can adjust variance %

# import numpy as np
# from sklearn import svm
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.metrics import classification_report, accuracy_score


# train_paths, test_paths, train_labels, test_labels = train_test_split(
#     features, labels, test_size=0.2, random_state=42, stratify=labels
# )

# # Step 2: Standardize the features
# scaler = StandardScaler()
# train_paths = scaler.fit_transform(train_paths)
# test_paths = scaler.transform(test_paths)

# # Step 3: Apply PCA
# pca = PCA(n_components=0.85)  # Retain 85% of the variance
# train_paths = pca.fit_transform(train_paths)
# test_paths = pca.transform(test_paths)

# %%
# linear

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, HalvingGridSearchCV

linear_svm = fine_tune("svm_linear", parameters_map)
linear_svm.fit(train_paths, train_labels)

# %%
print(f"Grid search linear SVM best parameters: {linear_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {linear_svm.best_score_}")

# %%
y_pred = linear_svm.predict(test_paths)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred)
recall = recall_score(test_labels, y_pred)
f1 = f1_score(test_labels, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# polynomial

poly_svm = fine_tune("svm_poly", parameters_map)
poly_svm.fit(train_paths, train_labels)

# %%
print(f"Grid search poly SVM best parameters: {poly_svm.best_params_}")
print(f"Cross validated score of the best poly SVM model: {poly_svm.best_score_}")

# %%
y_pred_poly = poly_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_poly)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_poly)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_poly)
recall = recall_score(test_labels, y_pred_poly)
f1 = f1_score(test_labels, y_pred_poly)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# rbf

rbf_svm = fine_tune("svm_rbf", parameters_map)
rbf_svm.fit(train_paths, train_labels)

# %%
# Check the best parameters
print("Best parameters found:", rbf_svm.best_params_)

# Check the kernel of the best estimator
print("Kernel used:", rbf_svm.best_estimator_.kernel)

# %%
y_pred_rbf = rbf_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_rbf)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_rbf)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_rbf)
recall = recall_score(test_labels, y_pred_rbf)
f1 = f1_score(test_labels, y_pred_rbf)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %% [markdown]
# <b>Testing conv2d_9 layer</b>

# %%
from tensorflow.keras.models import Model

# Function to extract features using the CNN
def extract_features(image_paths, model):
    features = []
    for img_path in image_paths:
        img_array = load_and_preprocess_image(img_path, target_size=(256, 256))
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Extract features
        feature = model.predict(img_array)
        features.append(feature.flatten())  # Flatten if necessary
    return np.array(features)

# extract features, from conv2d_8 layer
feature_extractor = Model(inputs=model.input, outputs=model.get_layer('conv2d_9').output)

# Extract features
features = extract_features(image_paths, feature_extractor)

# %%
np.save('features_conv2d_9.npy', features)  # Saves as a .npy file
print("saved")

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

train_paths, test_paths, train_labels, test_labels = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels
)

scaler = StandardScaler()
train_paths = scaler.fit_transform(train_paths)
test_paths = scaler.transform(test_paths)

# %%
# can try PCA afterwards, run above without PCA first // can adjust variance %

# import numpy as np
# from sklearn import svm
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.metrics import classification_report, accuracy_score


# train_paths, test_paths, train_labels, test_labels = train_test_split(
#     features, labels, test_size=0.2, random_state=42, stratify=labels
# )

# # Step 2: Standardize the features
# scaler = StandardScaler()
# train_paths = scaler.fit_transform(train_paths)
# test_paths = scaler.transform(test_paths)

# # Step 3: Apply PCA
# pca = PCA(n_components=0.85)  # Retain 85% of the variance
# train_paths = pca.fit_transform(train_paths)
# test_paths = pca.transform(test_paths)

# %%
# linear

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, HalvingGridSearchCV

linear_svm = fine_tune("svm_linear", parameters_map)
linear_svm.fit(train_paths, train_labels)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 100
# max_resources_: 8100
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 240
# n_resources: 100
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# ----------
# iter: 1
# n_candidates: 80
# n_resources: 300
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# ----------
# iter: 2
# n_candidates: 27
# n_resources: 900
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[219], line 4
#       1 # rbf
#       3 rbf_svm = fine_tune("svm_rbf", parameters_map)
# ----> 4 rbf_svm.fit(train_paths, train_labels)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search_successive_halving.py:251, in BaseSuccessiveHalving.fit(self, X, y, **params)
#     245 self._check_input_parameters(
#     246     X=X, y=y, split_params=routed_params.splitter.split
#     247 )
#     249 self._n_samples_orig = _num_samples(X)
# --> 251 super().fit(X, y=y, **params)
#     253 # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#     254 self.best_score_ = self.cv_results_["mean_test_score"][self.best_index_]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search_successive_halving.py:355, in BaseSuccessiveHalving._run_search(self, evaluate_candidates)
#     348     cv = self._checked_cv_orig
#     350 more_results = {
#     351     "iter": [itr] * n_candidates,
#     352     "n_resources": [n_resources] * n_candidates,
#     353 }
# --> 355 results = evaluate_candidates(
#     356     candidate_params, cv, more_results=more_results
#     357 )
#     359 n_candidates_to_keep = ceil(n_candidates / self.factor)
#     360 candidate_params = _top_k(results, n_candidates_to_keep, itr)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/lib/python3.11/threading.py:332, in Condition.wait(self, timeout)
#     330 if not gotit:
#     331     try:
# --> 332         self._waiters.remove(waiter)
#     333     except ValueError:
#     334         pass
#
# KeyboardInterrupt:

# %%
print(f"Grid search linear SVM best parameters: {linear_svm.best_params_}")
print(f"Cross validated score of the best linear SVM model: {linear_svm.best_score_}")

# %%
y_pred = linear_svm.predict(test_paths)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred)
recall = recall_score(test_labels, y_pred)
f1 = f1_score(test_labels, y_pred)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# polynomial

poly_svm = fine_tune("svm_poly", parameters_map)
poly_svm.fit(train_paths, train_labels)

# %%
print(f"Grid search poly SVM best parameters: {poly_svm.best_params_}")
print(f"Cross validated score of the best poly SVM model: {poly_svm.best_score_}")

# %%
y_pred_poly = poly_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_poly)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_poly)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_poly)
recall = recall_score(test_labels, y_pred_poly)
f1 = f1_score(test_labels, y_pred_poly)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# %%
# rbf

rbf_svm = fine_tune("svm_rbf", parameters_map)
rbf_svm.fit(train_paths, train_labels)

# %%
# Check the best parameters
print("Best parameters found:", rbf_svm.best_params_)

# Check the kernel of the best estimator
print("Kernel used:", rbf_svm.best_estimator_.kernel)

# %%
y_pred_rbf = rbf_svm.predict(test_paths)

# %%
# Calculate accuracy
accuracy = accuracy_score(test_labels, y_pred_rbf)  
print(f"Accuracy: {accuracy * 100:.2f}%")

# Calculate confusion matrix
conf_matrix = confusion_matrix(test_labels, y_pred_rbf)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, y_pred_rbf)
recall = recall_score(test_labels, y_pred_rbf)
f1 = f1_score(test_labels, y_pred_rbf)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
